# %%
# importing the dependencies
#%pip install tensorflow==1.9
import numpy as np # linear algebra
import pandas as pd # dataframe
import tensorflow as tf # Machine learning
from glob import glob # file handling
from tqdm import tqdm # progress bar
from collections import deque
# for simpler implementation of memory

import matplotlib.pyplot as plt # visualisation
# %matplotlib inline

# %% [markdown]
# ### Some helper functions below
#
# Below is the code for some helper functions and is consistent across various models.

# %%
# function to properly return the string of price
def format_price(price):
    return ("-$" if price < 0 else "$") + "{0:.2f}".format(abs(price))

def sigmoid(x):
    return 1/(1 + np.exp(-x))

# function to get the state
def get_state(data, t, n):
    d = t - n + 1
    if d >= 0:
        block = data[d:t+1]
    else:
        # pad with t0
        block = -d*[data[0]] + data[0:t+1].tolist()
        
    # block = data[d:t + 1] if d >= 0 else -d * [data[0]] + data[0:t + 1] # pad with t0
    
    # get results
    res = []
    for i in range(n - 1):
        res.append(sigmoid(block[i + 1] - block[i]))
    
    # return numpy array
    return np.array([res])

# %% [markdown]
# ### Load Data
#
# The code below is to load the data and is similar across various models.

# %%
# load the csv file
path_folder = './data_raw/'
file_path = glob(path_folder + '*.csv')[0]
stock_name = file_path.split('.')[-2].split('/')[-1]
data = pd.read_csv('data_raw/btc.csv')

# constants
LOG = False
episode_count = 10
window_size = 100
data = data['Close'].values # what our data is
len_data = len(data) - 847 # total information length
batch_size = 32 # minibatch size

# logs
loss_global = []
profits_global = []

# %%
plt.figure(figsize = (20, 8))
plt.plot(data)
plt.title(stock_name + '- BTC', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'IBM- BTC')

# %% [markdown]
# # Q-Learning with Replay Buffer

# %% [markdown]
# The Algorithm we are implementing here is the following:
#
# ![title](./blog_stuff/dqn_classic.png)
#
# For more details read the blog [here]().

# %%
class AgentDQN():
    # init functions
    def __init__(self, input_dim, scope, is_eval = False, epsilon_decay_steps = 1000):
        # input_dim: state size
        # is_eval: is being evaluated
        # scope: scope of the model
        self.state_size = input_dim
        self.action_space = 3 # sell, sit, buy
        self.memory = deque(maxlen = 10000)
        self.inventory = [] # holdings that we have
        self.scope = scope # name of scope
        self.is_eval = is_eval # whether in training or deployment
        self.gamma = 0.95 # discount factor

        # greedy-epsilon policy
        self.epsilon = 1.0
        self.epsilon_end = 0.01
        self.epsilon_decay_val = (self.epsilon - self.epsilon_end)/epsilon_decay_steps

        # code to load previously trained model --> skip for now
        # self.model = load_model("models/" + model_name) if is_eval else self._model()
        self._build_model()
        self._build_loss()
        self.initialize_network()

    # inhouse functions
    def _build_model(self):
        self.input_placeholder = tf.placeholder(tf.float32, [None, self.state_size], name = 'inputs')
        self.target_placeholder = tf.placeholder(tf.float32, [None, self.action_space], name = 'target_value')

        # layers
        h1 = tf.contrib.layers.fully_connected(self.input_placeholder, 64)
        h2 = tf.contrib.layers.fully_connected(h1, 32)
        h3 = tf.contrib.layers.fully_connected(h2, 8)
        self.action_pred = tf.contrib.layers.fully_connected(h3, self.action_space)

        # print the values
        print('inputs:', self.input_placeholder)
        print('target_value:', self.target_placeholder)
        print('action_pred:', self.action_pred)

    def _build_loss(self):
        self.loss = tf.reduce_mean(tf.square(self.target_placeholder - self.action_pred))
        print('loss:', self.loss)
        self.update_step = tf.train.AdamOptimizer(0.001).minimize(self.loss)

    # user callable functions
    def initialize_network(self):
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())

    def save_model(self, frozen = False):
        # code to save the model as frozen inference graph (optional) or 
        # checkpoint file (default)
        if frozen:
            # convert to frozen graph here
            model_path = 'some_path'
            print('Model saved at {0}'.format(some_path))
            return
        return

    # operation functions
    def act(self, state):
        if not self.is_eval and np.random.random() <= self.epsilon:
            return np.random.randint(self.action_space)

        # else use the model to predict action
        action_dist = self.sess.run(self.action_pred, feed_dict = {self.input_placeholder: state})
        return np.argmax(action_dist[0])

    def experience_replay(self, batch_size):
        # make the minibatch
        mini_batch = []
        mem_len = len(self.memory)
        for i in range(mem_len - batch_size + 1, mem_len):
            mini_batch.append(self.memory[i])

        # loss log
        loss_log = []

        for state, action, reward, next_state, done in mini_batch:
            target_s = reward
            if not done:
                # get predictions from model
                pred = self.sess.run(self.action_pred, feed_dict = {self.input_placeholder: next_state})

                # get the target value to be fit
                target_s = reward + self.gamma*np.amax(pred[0])

            # target value to be fit upon
            target_y = self.sess.run(self.action_pred, feed_dict = {self.input_placeholder: state})
            target_y[0][action] = target_s

            # train the model
            feed_dict = {self.input_placeholder: state, self.target_placeholder: target_y}
            loss, _ = self.sess.run([self.loss, self.update_step], feed_dict = feed_dict)

            # add to logs
            loss_log.append(loss)

        # reduce the value of epsilon
        if self.epsilon > self.epsilon_end:
            self.epsilon -= self.epsilon_decay_val

        # return loss
        return loss_log

# %%
# define the agent
agent = AgentDQN(window_size, 'model_pre')
# Out:
# inputs: Tensor("inputs_1:0", shape=(?, 100), dtype=float32)
# target_value: Tensor("target_value_1:0", shape=(?, 3), dtype=float32)
# action_pred: Tensor("fully_connected_7/Relu:0", shape=(?, 3), dtype=float32)
# loss: Tensor("Mean_1:0", shape=(), dtype=float32)

# %%
# run things
for e in range(episode_count):
    state = get_state(data, 0, window_size + 1)

    # init values for new episode
    total_profit = 0.0 # total profit in this epoch
    agent.inventory = [] # reset the inventory
    total_loss = [] # at each step what was the total loss
    mean_loss = [] # at each step what was the mean loss

    for t in tqdm(range(len_data)):
        action = agent.act(state)

        # next state
        next_state = get_state(data, t + 1, window_size + 1)
        reward = 0

        # now go according to actions
        if action == 2:
            # buy
            agent.inventory.append(data[t])
            if LOG:
                print('Buy:' + format_price(data[t]))


        elif action == 0 and len(agent.inventory) > 0:
            bought_price = agent.inventory.pop(0) # remove the first element and return the value
            profit = data[t] - bought_price # profit this iteration
            reward = max(data[t] - bought_price, 0) # reward
            total_profit += profit # add to total profit
            if LOG:
                print("Sell: " + format_price(data[t]) + " | Profit: " + format_price(profit))

        # condition for finish
        done = t == len_data - 1
        agent.memory.append((state, action, reward, next_state, done))
        state = next_state

        if done and LOG:
            print("Total Profit: " + format_price(total_profit))

        # train the model
        if len(agent.memory) > batch_size:
            losses = agent.experience_replay(batch_size)
            total_loss.append(np.sum(losses))
            mean_loss.append(np.mean(losses))

    # add the mean loss to global loss
    loss_global.append(np.mean(mean_loss))
    profits_global.append(total_profit)
    
    
    
    
    print('[*]Episode: {0}, loss: {1}, profits: {2}'.format(e, loss_global[-1], profits_global[-1]))
    
    
    total_profit = 0.0 # total profit in this epoch
    agent.inventory = [] # reset the inventory
    total_loss = [] # at each step what was the total loss
    mean_loss = [] # at each step what was the mean loss

    for t in tqdm(range(len_data, len_data+846)):
        action = agent.act(state)

        # next state
        next_state = get_state(data, t + 1, window_size + 1)
        reward = 0

        # now go according to actions
        if action == 2:
            # buy
            agent.inventory.append(data[t])
            if LOG:
                print('Buy:' + format_price(data[t]))


        elif action == 0 and len(agent.inventory) > 0:
            bought_price = agent.inventory.pop(0) # remove the first element and return the value
            profit = data[t] - bought_price # profit this iteration
            reward = max(data[t] - bought_price, 0) # reward
            total_profit += profit # add to total profit
        
        print("Sell VALIDATION: " + format_price(data[t]) + " | Profit_real: " + format_price(profit))
# Out:
#  56%|█████▌    | 1088/1960 [00:22<00:18, 46.42it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in exp
#
# 100%|██████████| 1960/1960 [00:41<00:00, 47.80it/s]
# [*]Episode: 0, loss: 96.84022521972656, profits: 5732.027583000001
#  21%|██▏       | 181/846 [00:00<00:00, 1805.00it/s]
# Sell VALIDATION: $9316.63 | Profit_real: $228.98
# Sell VALIDATION: $9508.99 | Profit_real: $228.98
# Sell VALIDATION: $9350.53 | Profit_real: $228.98
# Sell VALIDATION: $9392.88 | Profit_real: $228.98
# Sell VALIDATION: $9344.37 | Profit_real: $228.98
# Sell VALIDATION: $9293.52 | Profit_real: $228.98
# Sell VALIDATION: $9180.96 | Profit_real: $228.98
# Sell VALIDATION: $9613.42 | Profit_real: $228.98
# Sell VALIDATION: $9729.80 | Profit_real: $228.98
# Sell VALIDATION: $9795.94 | Profit_real: $228.98
# Sell VALIDATION: $9865.12 | Profit_real: $228.98
# Sell VALIDATION: $10116.67 | Profit_real: $228.98
# Sell VALIDATION: $9856.61 | Profit_real: $228.98
# Sell VALIDATION: $10208.24 | Profit_real: $228.98
# Sell VALIDATION: $10326.05 | Profit_real: $228.98
# Sell VALIDATION: $10214.38 | Profit_real: $228.98
# Sell VALIDATION: $10312.12 | Profit_real: $228.98
# Sell VALIDATION: $9889.42 | Profit_real: $228.98
# Sell VALIDATION: $9934.43 | Profit_real: $228.98
# Sell VALIDATION: $9690.14 | Profit_real: $228.98
# Sell VALIDATION: $10142.00 | Profit_real: $228.98
# Sell VALIDATION: $9633.39 | Profit_real: $228.98
# Sell VALIDATION: $9608.48 | Profit_real: $228.98
# Sell VALIDATION: $9686.44 | Profit_real: $228.98
# Sell VALIDATION: $9663.18 | Profit_real: $228.98
# Sell VALIDATION: $9924.52 | Profit_real: $228.98
# Sell VALIDATION: $9650.17 | Profit_real: $228.98
# Sell VALIDATION: $9341.71 | Profit_real: $228.98
# Sell VALIDATION: $8820.52 | Profit_real: $228.98
# Sell VALIDATION: $8784.49 | Profit_real: $228.98
# Sell VALIDATION: $8672.46 | Profit_real: $228.98
# Sell VALIDATION: $8599.51 | Profit_real: $228.98
# Sell VALIDATION: $8562.45 | Profit_real: $228.98
# Sell VALIDATION: $8869.67 | Profit_real: $228.98
# Sell VALIDATION: $8787.79 | Profit_real: $228.98
# Sell VALIDATION: $8755.25 | Profit_real: $228.98
# Sell VALIDATION: $9078.76 | Profit_real: $228.98
# Sell VALIDATION: $9122.55 | Profit_real: $228.98
# Sell VALIDATION: $8909.95 | Profit_real: $228.98
# Sell VALIDATION: $8108.12 | Profit_real: $228.98
# Sell VALIDATION: $7923.64 | Profit_real: $228.98
# Sell VALIDATION: $7909.73 | Profit_real: $228.98
# Sell VALIDATION: $7911.43 | Profit_real: $228.98
# Sell VALIDATION: $4970.79 | Profit_real: $228.98
# Sell VALIDATION: $5563.71 | Profit_real: $228.98
# Sell VALIDATION: $5200.37 | Profit_real: $228.98
# Sell VALIDATION: $5392.31 | Profit_real: $228.98
# Sell VALIDATION: $5014.48 | Profit_real: $228.98
# Sell VALIDATION: $5225.63 | Profit_real: $228.98
# Sell VALIDATION: $5238.44 | Profit_real: $228.98
# Sell VALIDATION: $6191.19 | Profit_real: $228.98
# Sell VALIDATION: $6198.78 | Profit_real: $228.98
# Sell VALIDATION: $6185.07 | Profit_real: $228.98
# Sell VALIDATION: $5830.25 | Profit_real: $228.98
# Sell VALIDATION: $6416.31 | Profit_real: $228.98
# Sell VALIDATION: $6734.80 | Profit_real: $228.98
# Sell VALIDATION: $6681.06 | Profit_real: $228.98
# Sell VALIDATION: $6716.44 | Profit_real: $228.98
# Sell VALIDATION: $6469.80 | Profit_real: $228.98
# Sell VALIDATION: $6242.19 | Profit_real: $228.98
# Sell VALIDATION: $5922.04 | Profit_real: $228.98
# Sell VALIDATION: $6429.84 | Profit_real: $228.98
# Sell VALIDATION: $6438.64 | Profit_real: $228.98
# Sell VALIDATION: $6606.78 | Profit_real: $228.98
# Sell VALIDATION: $6793.62 | Profit_real: $228.98
# Sell VALIDATION: $6733.39 | Profit_real: $228.98
# Sell VALIDATION: $6867.53 | Profit_real: $228.98
# Sell VALIDATION: $6791.13 | Profit_real: $228.98
# Sell VALIDATION: $7271.78 | Profit_real: $228.98
# Sell VALIDATION: $7176.41 | Profit_real: $228.98
# Sell VALIDATION: $7334.10 | Profit_real: $228.98
# Sell VALIDATION: $7302.09 | Profit_real: $228.98
# Sell VALIDATION: $6865.49 | Profit_real: $228.98
# Sell VALIDATION: $6859.08 | Profit_real: $228.98
# Sell VALIDATION: $6971.09 | Profit_real: $228.98
# Sell VALIDATION: $6845.04 | Profit_real: $228.98
# Sell VALIDATION: $6842.43 | Profit_real: $228.98
# Sell VALIDATION: $6642.11 | Profit_real: $228.98
# Sell VALIDATION: $7116.80 | Profit_real: $228.98
# Sell VALIDATION: $7096.18 | Profit_real: $228.98
# Sell VALIDATION: $7257.67 | Profit_real: $228.98
# Sell VALIDATION: $7189.42 | Profit_real: $228.98
# Sell VALIDATION: $6881.96 | Profit_real: $228.98
# Sell VALIDATION: $6880.32 | Profit_real: $228.98
# Sell VALIDATION: $7117.21 | Profit_real: $228.98
# Sell VALIDATION: $7429.72 | Profit_real: $228.98
# Sell VALIDATION: $7550.90 | Profit_real: $228.98
# Sell VALIDATION: $7569.94 | Profit_real: $228.98
# Sell VALIDATION: $7679.87 | Profit_real: $228.98
# Sell VALIDATION: $7795.60 | Profit_real: $228.98
# Sell VALIDATION: $7807.06 | Profit_real: $228.98
# Sell VALIDATION: $8801.04 | Profit_real: $228.98
# Sell VALIDATION: $8658.55 | Profit_real: $228.98
# Sell VALIDATION: $8864.77 | Profit_real: $228.98
# Sell VALIDATION: $8988.60 | Profit_real: $228.98
# Sell VALIDATION: $8897.47 | Profit_real: $228.98
# Sell VALIDATION: $8912.65 | Profit_real: $228.98
# Sell VALIDATION: $9003.07 | Profit_real: $228.98
# Sell VALIDATION: $9268.76 | Profit_real: $228.98
# Sell VALIDATION: $9951.52 | Profit_real: $228.98
# Sell VALIDATION: $9842.67 | Profit_real: $228.98
# Sell VALIDATION: $9593.90 | Profit_real: $228.98
# Sell VALIDATION: $8756.43 | Profit_real: $228.98
# Sell VALIDATION: $8601.80 | Profit_real: $228.98
# Sell VALIDATION: $8804.48 | Profit_real: $228.98
# Sell VALIDATION: $9269.99 | Profit_real: $228.98
# Sell VALIDATION: $9733.72 | Profit_real: $228.98
# Sell VALIDATION: $9328.20 | Profit_real: $228.98
# Sell VALIDATION: $9377.01 | Profit_real: $228.98
# Sell VALIDATION: $9670.74 | Profit_real: $228.98
# Sell VALIDATION: $9726.58 | Profit_real: $228.98
# Sell VALIDATION: $9729.04 | Profit_real: $228.98
# Sell VALIDATION: $9522.98 | Profit_real: $228.98
# Sell VALIDATION: $9081.76 | Profit_real: $228.98
# Sell VALIDATION: $9182.58 | Profit_real: $228.98
# Sell VALIDATION: $9209.29 | Profit_real: $228.98
# Sell VALIDATION: $8790.37 | Profit_real: $228.98
# Sell VALIDATION: $8906.93 | Profit_real: $228.98
# Sell VALIDATION: $8835.05 | Profit_real: $228.98
# Sell VALIDATION: $9181.02 | Profit_real: $228.98
# Sell VALIDATION: $9525.75 | Profit_real: $228.98
# Sell VALIDATION: $9439.12 | Profit_real: $228.98
# Sell VALIDATION: $9700.41 | Profit_real: $228.98
# Sell VALIDATION: $9461.06 | Profit_real: $228.98
# Sell VALIDATION: $10167.27 | Profit_real: $228.98
# Sell VALIDATION: $9529.80 | Profit_real: $228.98
# Sell VALIDATION: $9656.72 | Profit_real: $228.98
# Sell VALIDATION: $9800.64 | Profit_real: $228.98
# Sell VALIDATION: $9665.53 | Profit_real: $228.98
# Sell VALIDATION: $9653.68 | Profit_real: $228.98
# Sell VALIDATION: $9758.85 | Profit_real: $228.98
# Sell VALIDATION: $9771.49 | Profit_real: $228.98
# Sell VALIDATION: $9795.70 | Profit_real: $228.98
# Sell VALIDATION: $9870.09 | Profit_real: $228.98
# Sell VALIDATION: $9321.78 | Profit_real: $228.98
# Sell VALIDATION: $9480.84 | Profit_real: $228.98
# Sell VALIDATION: $9475.28 | Profit_real: $228.98
# Sell VALIDATION: $9386.79 | Profit_real: $228.98
# Sell VALIDATION: $9450.70 | Profit_real: $228.98
# Sell VALIDATION: $9538.02 | Profit_real: $228.98
# Sell VALIDATION: $9480.25 | Profit_real: $228.98
# Sell VALIDATION: $9411.84 | Profit_real: $228.98
# Sell VALIDATION: $9288.02 | Profit_real: $228.98
# Sell VALIDATION: $9332.34 | Profit_real: $228.98
# Sell VALIDATION: $9303.63 | Profit_real: $228.98
# Sell VALIDATION: $9648.72 | Profit_real: $228.98
# Sell VALIDATION: $9629.66 | Profit_real: $228.98
# Sell VALIDATION: $9313.61 | Profit_real: $228.98
# Sell VALIDATION: $9264.81 | Profit_real: $228.98
# Sell VALIDATION: $9162.92 | Profit_real: $228.98
# Sell VALIDATION: $9045.39 | Profit_real: $228.98
# Sell VALIDATION: $9143.58 | Profit_real: $228.98
# Sell VALIDATION: $9190.85 | Profit_real: $228.98
# Sell VALIDATION: $9137.99 | Profit_real: $228.98
# Sell VALIDATION: $9228.33 | Profit_real: $228.98
# Sell VALIDATION: $9123.41 | Profit_real: $228.98
# Sell VALIDATION: $9087.30 | Profit_real: $228.98
# Sell VALIDATION: $9132.49 | Profit_real: $228.98
# Sell VALIDATION: $9073.94 | Profit_real: $228.98
# Sell VALIDATION: $9375.47 | Profit_real: $228.98
# Sell VALIDATION: $9252.28 | Profit_real: $228.98
# Sell VALIDATION: $9428.33 | Profit_real: $228.98
# Sell VALIDATION: $9277.97 | Profit_real: $228.98
# Sell VALIDATION: $9278.81 | Profit_real: $228.98
# Sell VALIDATION: $9240.35 | Profit_real: $228.98
# Sell VALIDATION: $9276.50 | Profit_real: $228.98
# Sell VALIDATION: $9243.61 | Profit_real: $228.98
# Sell VALIDATION: $9243.21 | Profit_real: $228.98
# Sell VALIDATION: $9192.84 | Profit_real: $228.98
# Sell VALIDATION: $9132.23 | Profit_real: $228.98
# Sell VALIDATION: $9151.39 | Profit_real: $228.98
# Sell VALIDATION: $9159.04 | Profit_real: $228.98
# Sell VALIDATION: $9185.82 | Profit_real: $228.98
# Sell VALIDATION: $9164.23 | Profit_real: $228.98
# Sell VALIDATION: $9374.89 | Profit_real: $228.98
# Sell VALIDATION: $9525.36 | Profit_real: $228.98
# Sell VALIDATION: $9581.07 | Profit_real: $228.98
# Sell VALIDATION: $9536.89 | Profit_real: $228.98
# Sell VALIDATION: $9677.11 | Profit_real: $228.98
# Sell VALIDATION: $9905.17 | Profit_real: $228.98
# Sell VALIDATION: $10990.87 | Profit_real: $228.98
# Sell VALIDATION: $10912.82 | Profit_real: $228.98
# Sell VALIDATION: $11100.47 | Profit_real: $228.98
# Sell VALIDATION: $11111.21 | Profit_real: $228.98
# Sell VALIDATION: $11323.47 | Profit_real: $228.98
# Sell VALIDATION: $11759.59 | Profit_real: $228.98
# Sell VALIDATION: $11053.61 | Profit_real: $228.98
# Sell VALIDATION: $11246.35 | Profit_real: $228.98
# Sell VALIDATION: $11205.89 | Profit_real: $228.98
# Sell VALIDATION: $11747.02 | Profit_real: $228.98
# Sell VALIDATION: $11779.77 | Profit_real: $228.98
# Sell VALIDATION: $11601.47 | Profit_real: $228.98
# Sell VALIDATION: $11754.05 | Profit_real: $228.98
# Sell VALIDATION: $11675.74 | Profit_real: $228.98
# Sell VALIDATION: $11878.11 | Profit_real: $228.98
# Sell VALIDATION: $11410.53 | Profit_real: $228.98
# Sell VALIDATION: $11584.93 | Profit_real: $228.98
# Sell VALIDATION: $11784.14 | Profit_real: $228.98
# Sell VALIDATION: $11768.87 | Profit_real: $228.98
# Sell VALIDATION: $11865.70 | Profit_real: $228.98
# Sell VALIDATION: $11892.80 | Profit_real: $228.98
# Sell VALIDATION: $12254.40 | Profit_real: $228.98
# Sell VALIDATION: $11991.23 | Profit_real: $228.98
# Sell VALIDATION: $11758.28 | Profit_real: $228.98
# Sell VALIDATION: $11878.37 | Profit_real: $228.98
# Sell VALIDATION: $11592.49 | Profit_real: $228.98
# Sell VALIDATION: $11681.83 | Profit_real: $228.98
# Sell VALIDATION: $11664.85 | Profit_real: $228.98
# Sell VALIDATION: $11774.60 | Profit_real: $228.98
# Sell VALIDATION: $11366.13 | Profit_real: $228.98
# Sell VALIDATION: $11488.36 | Profit_real: $228.98
# Sell VALIDATION: $11323.40 | Profit_real: $228.98
# Sell VALIDATION: $11542.50 | Profit_real: $228.98
# Sell VALIDATION: $11506.87 | Profit_real: $228.98
# Sell VALIDATION: $11711.51 | Profit_real: $228.98
# Sell VALIDATION: $11680.82 | Profit_real: $228.98
# Sell VALIDATION: $11970.48 | Profit_real: $228.98
# Sell VALIDATION: $11414.03 | Profit_real: $228.98
# Sell VALIDATION: $10245.30 | Profit_real: $228.98
# Sell VALIDATION: $10511.81 | Profit_real: $228.98
# Sell VALIDATION: $10169.57 | Profit_real: $228.98
# Sell VALIDATION: $10280.35 | Profit_real: $228.98
# Sell VALIDATION: $10369.56 | Profit_real: $228.98
# Sell VALIDATION: $10131.52 | Profit_real: $228.98
# Sell VALIDATION: $10242.35 | Profit_real: $228.98
# Sell VALIDATION: $10363.14 | Profit_real: $228.98
# Sell VALIDATION: $10400.92 | Profit_real: $228.98
# Sell VALIDATION: $10442.17 | Profit_real: $228.98
# Sell VALIDATION: $10323.76 | Profit_real: $228.98
# Sell VALIDATION: $10680.84 | Profit_real: $228.98
# Sell VALIDATION: $10796.95 | Profit_real: $228.98
# Sell VALIDATION: $10974.91 | Profit_real: $228.98
# Sell VALIDATION: $10948.99 | Profit_real: $228.98
# Sell VALIDATION: $10944.59 | Profit_real: $228.98
# Sell VALIDATION: $11094.35 | Profit_real: $228.98
# Sell VALIDATION: $10938.27 | Profit_real: $228.98
# Sell VALIDATION: $10462.26 | Profit_real: $228.98
# Sell VALIDATION: $10538.46 | Profit_real: $228.98
# Sell VALIDATION: $10246.19 | Profit_real: $228.98
# Sell VALIDATION: $10760.07 | Profit_real: $228.98
# Sell VALIDATION: $10692.72 | Profit_real: $228.98
# Sell VALIDATION: $10750.72 | Profit_real: $228.98
# Sell VALIDATION: $10775.27 | Profit_real: $228.98
# Sell VALIDATION: $10709.65 | Profit_real: $228.98
# Sell VALIDATION: $10844.64 | Profit_real: $228.98
# Sell VALIDATION: $10784.49 | Profit_real: $228.98
# Sell VALIDATION: $10619.45 | Profit_real: $228.98
# Sell VALIDATION: $10575.97 | Profit_real: $228.98
# Sell VALIDATION: $10549.33 | Profit_real: $228.98
# Sell VALIDATION: $10669.58 | Profit_real: $228.98
# Sell VALIDATION: $10793.34 | Profit_real: $228.98
# Sell VALIDATION: $10604.41 | Profit_real: $228.98
# Sell VALIDATION: $10668.97 | Profit_real: $228.98
# Sell VALIDATION: $10915.69 | Profit_real: $228.98
# Sell VALIDATION: $11064.46 | Profit_real: $228.98
# Sell VALIDATION: $11296.36 | Profit_real: $228.98
# Sell VALIDATION: $11384.18 | Profit_real: $228.98
# Sell VALIDATION: $11555.36 | Profit_real: $228.98
# Sell VALIDATION: $11425.90 | Profit_real: $228.98
# Sell VALIDATION: $11429.51 | Profit_real: $228.98
# Sell VALIDATION: $11495.35 | Profit_real: $228.98
# Sell VALIDATION: $11322.12 | Profit_real: $228.98
# Sell VALIDATION: $11358.10 | Profit_real: $228.98
# Sell VALIDATION: $11483.36 | Profit_real: $228.98
# Sell VALIDATION: $11742.04 | Profit_real: $228.98
# Sell VALIDATION: $11916.33 | Profit_real: $228.98
# Sell VALIDATION: $12823.69 | Profit_real: $228.98
# Sell VALIDATION: $12965.89 | Profit_real: $228.98
# Sell VALIDATION: $12931.54 | Profit_real: $228.98
# Sell VALIDATION: $13108.06 | Profit_real: $228.98
# Sell VALIDATION: $13031.17 | Profit_real: $228.98
# Sell VALIDATION: $13075.25 | Profit_real: $228.98
# Sell VALIDATION: $13654.22 | Profit_real: $228.98
# Sell VALIDATION: $13271.29 | Profit_real: $228.98
# Sell VALIDATION: $13437.88 | Profit_real: $228.98
# Sell VALIDATION: $13546.52 | Profit_real: $228.98
# Sell VALIDATION: $13781.00 | Profit_real: $228.98
# Sell VALIDATION: $13737.11 | Profit_real: $228.98
# Sell VALIDATION: $13550.49 | Profit_real: $228.98
# Sell VALIDATION: $13950.30 | Profit_real: $228.98
# Sell VALIDATION: $14133.71 | Profit_real: $228.98
# Sell VALIDATION: $15579.85 | Profit_real: $228.98
# Sell VALIDATION: $15565.88 | Profit_real: $228.98
# Sell VALIDATION: $14833.75 | Profit_real: $228.98
# Sell VALIDATION: $15479.57 | Profit_real: $228.98
# Sell VALIDATION: $15332.32 | Profit_real: $228.98
# Sell VALIDATION: $15290.90 | Profit_real: $228.98
# Sell VALIDATION: $15701.34 | Profit_real: $228.98
# Sell VALIDATION: $16276.34 | Profit_real: $228.98
# Sell VALIDATION: $16317.81 | Profit_real: $228.98
# Sell VALIDATION: $16068.14 | Profit_real: $228.98
# Sell VALIDATION: $15955.59 | Profit_real: $228.98
# Sell VALIDATION: $16716.11 | Profit_real: $228.98
# Sell VALIDATION: $17645.41 | Profit_real: $228.98
# Sell VALIDATION: $17804.01 | Profit_real: $228.98
# Sell VALIDATION: $17817.09 | Profit_real: $228.98
# Sell VALIDATION: $18621.31 | Profit_real: $228.98
# Sell VALIDATION: $18642.23 | Profit_real: $228.98
# Sell VALIDATION: $18370.00 | Profit_real: $228.98
# Sell VALIDATION: $18364.12 | Profit_real: $228.98
# Sell VALIDATION: $19107.46 | Profit_real: $228.98
# Sell VALIDATION: $18732.12 | Profit_real: $228.98
# Sell VALIDATION: $17150.62 | Profit_real: $228.98
# Sell VALIDATION: $17108.40 | Profit_real: $228.98
# Sell VALIDATION: $17717.41 | Profit_real: $228.98
# Sell VALIDATION: $18177.48 | Profit_real: $228.98
# Sell VALIDATION: $19625.84 | Profit_real: $228.98
# Sell VALIDATION: $18803.00 | Profit_real: $228.98
# Sell VALIDATION: $19201.09 | Profit_real: $228.98
# Sell VALIDATION: $19445.40 | Profit_real: $244.31
# Sell VALIDATION: $18699.77 | Profit_real: $244.31
# Sell VALIDATION: $19154.23 | Profit_real: $244.31
# Sell VALIDATION: $19345.12 | Profit_real: $244.31
# Sell VALIDATION: $19191.63 | Profit_real: $244.31
# Sell VALIDATION: $18321.14 | Profit_real: $244.31
# Sell VALIDATION: $18553.92 | Profit_real: $244.31
# Sell VALIDATION: $18264.99 | Profit_real: $244.31
# Sell VALIDATION: $18058.90 | Profit_real: $244.31
# Sell VALIDATION: $18803.66 | Profit_real: $244.31
# Sell VALIDATION: $19142.38 | Profit_real: $244.31
# Sell VALIDATION: $19246.64 | Profit_real: $244.31
# Sell VALIDATION: $19417.08 | Profit_real: $244.31
# Sell VALIDATION: $21310.60 | Profit_real: $244.31
# Sell VALIDATION: $22805.16 | Profit_real: $244.31
# Sell VALIDATION: $23137.96 | Profit_real: $244.31
# Sell VALIDATION: $23869.83 | Profit_real: $244.31
# Sell VALIDATION: $23477.29 | Profit_real: $244.31
# Sell VALIDATION: $22803.08 | Profit_real: $244.31
# Sell VALIDATION: $23783.03 | Profit_real: $244.31
# Sell VALIDATION: $23241.35 | Profit_real: $244.31
# Sell VALIDATION: $23735.95 | Profit_real: $244.31
# Sell VALIDATION: $24664.79 | Profit_real: $244.31
# Sell VALIDATION: $26437.04 | Profit_real: $244.31
# Sell VALIDATION: $26272.29 | Profit_real: $244.31
# Sell VALIDATION: $27084.81 | Profit_real: $244.31
# Sell VALIDATION: $27362.44 | Profit_real: $244.31
# Sell VALIDATION: $28840.95 | Profit_real: $244.31
# Sell VALIDATION: $29001.72 | Profit_real: $244.31
# Sell VALIDATION: $29374.15 | Profit_real: $244.31
# Sell VALIDATION: $32127.27 | Profit_real: $244.31
# Sell VALIDATION: $32782.02 | Profit_real: $244.31
# Sell VALIDATION: $31971.91 | Profit_real: $244.31
# Sell VALIDATION: $33992.43 | Profit_real: $244.31
# Sell VALIDATION: $36824.36 | Profit_real: $244.31
# Sell VALIDATION: $39371.04 | Profit_real: $244.31
# Sell VALIDATION: $40797.61 | Profit_real: $244.31
# Sell VALIDATION: $40254.55 | Profit_real: $244.31
# Sell VALIDATION: $38356.44 | Profit_real: $244.31
# Sell VALIDATION: $35566.66 | Profit_real: $244.31
# Sell VALIDATION: $33922.96 | Profit_real: $244.31
# Sell VALIDATION: $10208.24 | Profit_real: $1830.30
# Sell VALIDATION: $10326.05 | Profit_real: $1830.30
# Sell VALIDATION: $10214.38 | Profit_real: $1830.30
# Sell VALIDATION: $10312.12 | Profit_real: $1830.30
# Sell VALIDATION: $9889.42 | Profit_real: $1830.30
# Sell VALIDATION: $9934.43 | Profit_real: $1830.30
# Sell VALIDATION: $9690.14 | Profit_real: $1830.30
# Sell VALIDATION: $10142.00 | Profit_real: $1830.30
# Sell VALIDATION: $9633.39 | Profit_real: $1830.30
# Sell VALIDATION: $9608.48 | Profit_real: $1830.30
# Sell VALIDATION: $9686.44 | Profit_real: $1830.30
# Sell VALIDATION: $9663.18 | Profit_real: $1830.30
# Sell VALIDATION: $9924.52 | Profit_real: $1830.30
# Sell VALIDATION: $9650.17 | Profit_real: $1830.30
# Sell VALIDATION: $9341.71 | Profit_real: $1830.30
# Sell VALIDATION: $8820.52 | Profit_real: $1830.30
# Sell VALIDATION: $8784.49 | Profit_real: $1830.30
# Sell VALIDATION: $8672.46 | Profit_real: $1830.30
# Sell VALIDATION: $8599.51 | Profit_real: $1830.30
# Sell VALIDATION: $8562.45 | Profit_real: $1830.30
# Sell VALIDATION: $8869.67 | Profit_real: $1830.30
# Sell VALIDATION: $8787.79 | Profit_real: $1830.30
# Sell VALIDATION: $8755.25 | Profit_real: $1830.30
# Sell VALIDATION: $9078.76 | Profit_real: $1830.30
# Sell VALIDATION: $9122.55 | Profit_real: $1830.30
# Sell VALIDATION: $8909.95 | Profit_real: $1830.30
# Sell VALIDATION: $8108.12 | Profit_real: $1830.30
# Sell VALIDATION: $7923.64 | Profit_real: $1830.30
# Sell VALIDATION: $7909.73 | Profit_real: $1830.30
# Sell VALIDATION: $7911.43 | Profit_real: $1830.30
# Sell VALIDATION: $4970.79 | Profit_real: $1830.30
# Sell VALIDATION: $5563.71 | Profit_real: $1830.30
# Sell VALIDATION: $5200.37 | Profit_real: $1830.30
# Sell VALIDATION: $5392.31 | Profit_real: $1830.30
# Sell VALIDATION: $5014.48 | Profit_real: $1830.30
# Sell VALIDATION: $5225.63 | Profit_real: $1830.30
# Sell VALIDATION: $5238.44 | Profit_real: $1830.30
# Sell VALIDATION: $6191.19 | Profit_real: $1830.30
# Sell VALIDATION: $6198.78 | Profit_real: $1830.30
# Sell VALIDATION: $6185.07 | Profit_real: $1830.30
# Sell VALIDATION: $5830.25 | Profit_real: $1830.30
# Sell VALIDATION: $6416.31 | Profit_real: $1830.30
# Sell VALIDATION: $6734.80 | Profit_real: $1830.30
# Sell VALIDATION: $6681.06 | Profit_real: $1830.30
# Sell VALIDATION: $6716.44 | Profit_real: $1830.30
# Sell VALIDATION: $6469.80 | Profit_real: $1830.30
# Sell VALIDATION: $6242.19 | Profit_real: $1830.30
# Sell VALIDATION: $5922.04 | Profit_real: $1830.30
# Sell VALIDATION: $6429.84 | Profit_real: $1830.30
# Sell VALIDATION: $6438.64 | Profit_real: $1830.30
# Sell VALIDATION: $6606.78 | Profit_real: $1830.30
# Sell VALIDATION: $6793.62 | Profit_real: $1830.30
# Sell VALIDATION: $6733.39 | Profit_real: $1830.30
# Sell VALIDATION: $6867.53 | Profit_real: $1830.30
# Sell VALIDATION: $6791.13 | Profit_real: $1830.30
# Sell VALIDATION: $7271.78 | Profit_real: $1830.30
# Sell VALIDATION: $7176.41 | Profit_real: $1830.30
# Sell VALIDATION: $7334.10 | Profit_real: $1830.30
# Sell VALIDATION: $7302.09 | Profit_real: $1830.30
# Sell VALIDATION: $6865.49 | Profit_real: $1830.30
# Sell VALIDATION: $6859.08 | Profit_real: $1830.30
# Sell VALIDATION: $6971.09 | Profit_real: $1830.30
# Sell VALIDATION: $6845.04 | Profit_real: $1830.30
# Sell VALIDATION: $6842.43 | Profit_real: $1830.30
# Sell VALIDATION: $6642.11 | Profit_real: $1830.30
# Sell VALIDATION: $7116.80 | Profit_real: $1830.30
# Sell VALIDATION: $7096.18 | Profit_real: $1830.30
# Sell VALIDATION: $7257.67 | Profit_real: $1830.30
# Sell VALIDATION: $7189.42 | Profit_real: $1830.30
# Sell VALIDATION: $6881.96 | Profit_real: $1830.30
# Sell VALIDATION: $6880.32 | Profit_real: $1830.30
# Sell VALIDATION: $7117.21 | Profit_real: $1830.30
# Sell VALIDATION: $7429.72 | Profit_real: $1830.30
# Sell VALIDATION: $7550.90 | Profit_real: $1830.30
# Sell VALIDATION: $7569.94 | Profit_real: $1830.30
# Sell VALIDATION: $7679.87 | Profit_real: $1830.30
# Sell VALIDATION: $7795.60 | Profit_real: $1830.30
# Sell VALIDATION: $7807.06 | Profit_real: $1830.30
# Sell VALIDATION: $8801.04 | Profit_real: $1830.30
# Sell VALIDATION: $8658.55 | Profit_real: $1830.30
# Sell VALIDATION: $8864.77 | Profit_real: $1830.30
# Sell VALIDATION: $8988.60 | Profit_real: $1830.30
# Sell VALIDATION: $8897.47 | Profit_real: $1830.30
# Sell VALIDATION: $8912.65 | Profit_real: $1830.30
# Sell VALIDATION: $9003.07 | Profit_real: $1830.30
# Sell VALIDATION: $9268.76 | Profit_real: $1830.30
# Sell VALIDATION: $9951.52 | Profit_real: $1830.30
# Sell VALIDATION: $9842.67 | Profit_real: $1830.30
# Sell VALIDATION: $9593.90 | Profit_real: $1830.30
# Sell VALIDATION: $8756.43 | Profit_real: $1830.30
# Sell VALIDATION: $8601.80 | Profit_real: $1830.30
# Sell VALIDATION: $8804.48 | Profit_real: $1830.30
# ...
# Sell VALIDATION: $31421.54 | Profit_real: $1870.97
# Sell VALIDATION: $31533.07 | Profit_real: $1870.97
# Sell VALIDATION: $31796.81 | Profit_real: $1870.97
# Sell VALIDATION: $30817.83 | Profit_real: $1870.97
# Sell VALIDATION: $29807.35 | Profit_real: $1870.97
# Sell VALIDATION: $32110.69 | Profit_real: $1870.97
# Sell VALIDATION: $32313.11 | Profit_real: $1870.97
# Sell VALIDATION: $33581.55 | Profit_real: $1870.97
# Sell VALIDATION: $34292.45 | Profit_real: $1870.97
# Sell VALIDATION: $35350.19 | Profit_real: $1870.97
# Sell VALIDATION: $37337.54 | Profit_real: $1870.97
# Sell VALIDATION: $39406.94 | Profit_real: $1870.97
# Sell VALIDATION: $39995.91 | Profit_real: $1870.97
# Sell VALIDATION: $40008.42 | Profit_real: $1870.97
# Sell VALIDATION: $42235.55 | Profit_real: $1870.97
# Sell VALIDATION: $41626.20 | Profit_real: $1870.97
# Sell VALIDATION: $39974.89 | Profit_real: $1870.97
# Sell VALIDATION: $39201.95 | Profit_real: $1870.97
# Sell VALIDATION: $38152.98 | Profit_real: $1870.97
# Sell VALIDATION: $39747.50 | Profit_real: $1870.97
# Sell VALIDATION: $40869.55 | Profit_real: $1870.97
# Sell VALIDATION: $42816.50 | Profit_real: $1870.97
# Sell VALIDATION: $44555.80 | Profit_real: $1870.97
# Sell VALIDATION: $43798.12 | Profit_real: $1870.97
# Sell VALIDATION: $46365.40 | Profit_real: $1870.97
# Sell VALIDATION: $45585.03 | Profit_real: $1870.97
# Sell VALIDATION: $45593.64 | Profit_real: $1870.97
# Sell VALIDATION: $44428.29 | Profit_real: $1870.97
# Sell VALIDATION: $47793.32 | Profit_real: $1870.97
# Sell VALIDATION: $47096.95 | Profit_real: $1870.97
# Sell VALIDATION: $47047.00 | Profit_real: $1870.97
# Sell VALIDATION: $46004.48 | Profit_real: $1870.97
# Sell VALIDATION: $44695.36 | Profit_real: $1870.97
# Sell VALIDATION: $44801.19 | Profit_real: $1870.97
# Sell VALIDATION: $46717.58 | Profit_real: $1870.97
# Sell VALIDATION: $49339.18 | Profit_real: $1870.97
# Sell VALIDATION: $48905.49 | Profit_real: $1870.97
# Sell VALIDATION: $49321.65 | Profit_real: $1870.97
# Sell VALIDATION: $49546.15 | Profit_real: $1870.97
# Sell VALIDATION: $47706.12 | Profit_real: $1870.97
# Sell VALIDATION: $48960.79 | Profit_real: $1870.97
# Sell VALIDATION: $46942.22 | Profit_real: $1870.97
# Sell VALIDATION: $49058.67 | Profit_real: $1870.97
# Sell VALIDATION: $48902.40 | Profit_real: $1870.97
# Sell VALIDATION: $48829.83 | Profit_real: $1870.97
# Sell VALIDATION: $47054.98 | Profit_real: $1870.97
# Sell VALIDATION: $47166.69 | Profit_real: $1870.97
# Sell VALIDATION: $48847.03 | Profit_real: $1870.97
# Sell VALIDATION: $49327.72 | Profit_real: $1870.97
# Sell VALIDATION: $50025.38 | Profit_real: $1870.97
# Sell VALIDATION: $49944.62 | Profit_real: $1870.97
# Sell VALIDATION: $51753.41 | Profit_real: $1870.97
# Sell VALIDATION: $52633.54 | Profit_real: $1870.97
# Sell VALIDATION: $46811.13 | Profit_real: $1870.97
# Sell VALIDATION: $46091.39 | Profit_real: $1870.97
# Sell VALIDATION: $46391.42 | Profit_real: $1870.97
# Sell VALIDATION: $44883.91 | Profit_real: $1870.97
# Sell VALIDATION: $45201.46 | Profit_real: $1870.97
# Sell VALIDATION: $46063.27 | Profit_real: $1870.97
# Sell VALIDATION: $44963.07 | Profit_real: $1870.97
# Sell VALIDATION: $47092.49 | Profit_real: $1870.97
# Sell VALIDATION: $48176.35 | Profit_real: $1870.97
# Sell VALIDATION: $47783.36 | Profit_real: $1870.97
# Sell VALIDATION: $47267.52 | Profit_real: $1870.97
# Sell VALIDATION: $48278.36 | Profit_real: $1870.97
# Sell VALIDATION: $47260.22 | Profit_real: $1870.97
# Sell VALIDATION: $42843.80 | Profit_real: $1870.97
# Sell VALIDATION: $40693.68 | Profit_real: $1870.97
# Sell VALIDATION: $43574.51 | Profit_real: $1870.97
# Sell VALIDATION: $44895.10 | Profit_real: $1870.97
# Sell VALIDATION: $42839.75 | Profit_real: $1870.97
# Sell VALIDATION: $42716.59 | Profit_real: $1870.97
# Sell VALIDATION: $43208.54 | Profit_real: $1870.97
# Sell VALIDATION: $42235.73 | Profit_real: $1870.97
# Sell VALIDATION: $41034.54 | Profit_real: $1870.97
# Sell VALIDATION: $41564.36 | Profit_real: $1870.97
# Sell VALIDATION: $43790.89 | Profit_real: $1870.97
# Sell VALIDATION: $48116.94 | Profit_real: $1870.97
# Sell VALIDATION: $47711.49 | Profit_real: $1870.97
# Sell VALIDATION: $48199.95 | Profit_real: $1870.97
# Sell VALIDATION: $49112.90 | Profit_real: $1870.97
# Sell VALIDATION: $51514.81 | Profit_real: $1870.97
# Sell VALIDATION: $55361.45 | Profit_real: $1870.97
# Sell VALIDATION: $53805.98 | Profit_real: $1870.97
# Sell VALIDATION: $53967.85 | Profit_real: $1870.97
# Sell VALIDATION: $54968.22 | Profit_real: $1870.97
# Sell VALIDATION: $54771.58 | Profit_real: $1870.97
# Sell VALIDATION: $57484.79 | Profit_real: $1870.97
# Sell VALIDATION: $56041.06 | Profit_real: $1870.97
# Sell VALIDATION: $57401.10 | Profit_real: $1870.97
# Sell VALIDATION: $57321.52 | Profit_real: $1870.97
# Sell VALIDATION: $61593.95 | Profit_real: $1870.97
# Sell VALIDATION: $60892.18 | Profit_real: $1870.97
# Sell VALIDATION: $61553.62 | Profit_real: $1870.97
# Sell VALIDATION: $62026.08 | Profit_real: $1870.97
# Sell VALIDATION: $64261.99 | Profit_real: $1870.97
# Sell VALIDATION: $65992.84 | Profit_real: $1870.97
# Sell VALIDATION: $62210.17 | Profit_real: $1870.97
# Sell VALIDATION: $60692.27 | Profit_real: $1870.97
# Sell VALIDATION: $61393.62 | Profit_real: $1870.97
# Sell VALIDATION: $60930.84 | Profit_real: $1870.97
# Sell VALIDATION: $63039.82 | Profit_real: $1870.97
# Sell VALIDATION: $60363.79 | Profit_real: $1870.97
# Sell VALIDATION: $58482.39 | Profit_real: $1870.97
# Sell VALIDATION: $60622.14 | Profit_real: $1870.97
# Sell VALIDATION: $62227.96 | Profit_real: $1870.97
# Sell VALIDATION: $61888.83 | Profit_real: $1870.97
# Sell VALIDATION: $61318.96 | Profit_real: $1870.97
# Sell VALIDATION: $61004.41 | Profit_real: $1870.97
# Sell VALIDATION: $63226.40 | Profit_real: $1870.97
# Sell VALIDATION: $62970.05 | Profit_real: $1870.97
# Sell VALIDATION: $61452.23 | Profit_real: $1870.97
# Sell VALIDATION: $61125.68 | Profit_real: $1870.97
# Sell VALIDATION: $61527.48 | Profit_real: $1870.97
# Sell VALIDATION: $63326.99 | Profit_real: $1870.97
# Sell VALIDATION: $67566.83 | Profit_real: $1870.97
# Sell VALIDATION: $66971.83 | Profit_real: $1870.97
# Sell VALIDATION: $64995.23 | Profit_real: $1870.97
# Sell VALIDATION: $64949.96 | Profit_real: $1870.97
# Sell VALIDATION: $64155.94 | Profit_real: $1870.97
# Sell VALIDATION: $64469.53 | Profit_real: $1870.97
# Sell VALIDATION: $65466.84 | Profit_real: $1870.97
# Sell VALIDATION: $63557.87 | Profit_real: $1870.97
# Sell VALIDATION: $60161.25 | Profit_real: $1870.97
# Sell VALIDATION: $60368.01 | Profit_real: $1870.97
# Sell VALIDATION: $56942.14 | Profit_real: $1870.97
# Sell VALIDATION: $58119.58 | Profit_real: $1870.97
# Sell VALIDATION: $59697.20 | Profit_real: $1870.97
# Sell VALIDATION: $58730.48 | Profit_real: $1870.97
# Sell VALIDATION: $56289.29 | Profit_real: $1870.97
# Sell VALIDATION: $57569.07 | Profit_real: $1870.97
# Sell VALIDATION: $56280.43 | Profit_real: $1870.97
# Sell VALIDATION: $57274.68 | Profit_real: $1870.97
# Sell VALIDATION: $53569.77 | Profit_real: $1870.97
# Sell VALIDATION: $54815.08 | Profit_real: $1870.97
# Sell VALIDATION: $57248.46 | Profit_real: $1870.97
# Sell VALIDATION: $57806.57 | Profit_real: $1870.97
# Sell VALIDATION: $57005.43 | Profit_real: $1870.97
# Sell VALIDATION: $57229.83 | Profit_real: $1870.97
# Sell VALIDATION: $56477.82 | Profit_real: $1870.97
# Sell VALIDATION: $53598.25 | Profit_real: $1870.97
# Sell VALIDATION: $49200.70 | Profit_real: $1870.97
# Sell VALIDATION: $49368.85 | Profit_real: $1870.97
# Sell VALIDATION: $50582.62 | Profit_real: $1870.97
# Sell VALIDATION: $50700.09 | Profit_real: $1870.97
# Sell VALIDATION: $50504.80 | Profit_real: $1870.97
# Sell VALIDATION: $47672.12 | Profit_real: $1870.97
# Sell VALIDATION: $47243.30 | Profit_real: $1870.97
# Sell VALIDATION: $49362.51 | Profit_real: $1870.97
# Sell VALIDATION: $50098.34 | Profit_real: $1870.97
# Sell VALIDATION: $46737.48 | Profit_real: $1870.97
# Sell VALIDATION: $46612.63 | Profit_real: $1870.97
# Sell VALIDATION: $48896.72 | Profit_real: $1870.97
# Sell VALIDATION: $47665.43 | Profit_real: $1870.97
# Sell VALIDATION: $46202.14 | Profit_real: $1870.97
# Sell VALIDATION: $46848.78 | Profit_real: $1870.97
# Sell VALIDATION: $46707.02 | Profit_real: $1870.97
# Sell VALIDATION: $46880.28 | Profit_real: $1870.97
# Sell VALIDATION: $48936.61 | Profit_real: $1870.97
# 100%|██████████| 846/846 [00:00<00:00, 1706.68it/s]
# Sell VALIDATION: $48628.51 | Profit_real: $1870.97
# Sell VALIDATION: $50784.54 | Profit_real: $1870.97
# Sell VALIDATION: $50822.20 | Profit_real: $1870.97
# Sell VALIDATION: $50429.86 | Profit_real: $1870.97
# Sell VALIDATION: $50809.52 | Profit_real: $1870.97
# Sell VALIDATION: $50640.42 | Profit_real: $1870.97
# Sell VALIDATION: $47588.86 | Profit_real: $1870.97
# Sell VALIDATION: $46444.71 | Profit_real: $1870.97
# Sell VALIDATION: $47178.12 | Profit_real: $1870.97
# Sell VALIDATION: $46306.45 | Profit_real: $1870.97
# Sell VALIDATION: $47686.81 | Profit_real: $1870.97
# Sell VALIDATION: $47345.22 | Profit_real: $1870.97
# Sell VALIDATION: $46458.12 | Profit_real: $1870.97
# Sell VALIDATION: $45897.57 | Profit_real: $1870.97
# Sell VALIDATION: $43569.00 | Profit_real: $1870.97
# Sell VALIDATION: $43160.93 | Profit_real: $1870.97
# Sell VALIDATION: $41557.90 | Profit_real: $1870.97
# Sell VALIDATION: $41733.94 | Profit_real: $1870.97
# Sell VALIDATION: $41911.60 | Profit_real: $1870.97
# Sell VALIDATION: $41821.26 | Profit_real: $1870.97
# Sell VALIDATION: $42735.86 | Profit_real: $1870.97
# Sell VALIDATION: $43949.10 | Profit_real: $1870.97
# Sell VALIDATION: $42591.57 | Profit_real: $1870.97
# Sell VALIDATION: $43099.70 | Profit_real: $1870.97
# Sell VALIDATION: $43177.40 | Profit_real: $1870.97
# Sell VALIDATION: $43113.88 | Profit_real: $1870.97
# Sell VALIDATION: $42250.55 | Profit_real: $1870.97
# Sell VALIDATION: $42375.63 | Profit_real: $1870.97
# Sell VALIDATION: $41744.33 | Profit_real: $1870.97
# Sell VALIDATION: $40680.42 | Profit_real: $1870.97
# Sell VALIDATION: $36457.32 | Profit_real: $1870.97
# Sell VALIDATION: $35030.25 | Profit_real: $1870.97
# Sell VALIDATION: $36276.80 | Profit_real: $1870.97
# Sell VALIDATION: $36654.33 | Profit_real: $1870.97
# Sell VALIDATION: $36954.00 | Profit_real: $1870.97
# Sell VALIDATION: $36852.12 | Profit_real: $1870.97
# Sell VALIDATION: $37138.23 | Profit_real: $1870.97
# Sell VALIDATION: $37784.33 | Profit_real: $1870.97
# Sell VALIDATION: $38138.18 | Profit_real: $1870.97
# Sell VALIDATION: $37917.60 | Profit_real: $1870.97
# Sell VALIDATION: $38483.12 | Profit_real: $1870.97
# Sell VALIDATION: $38743.27 | Profit_real: $1870.97
# Sell VALIDATION: $36952.98 | Profit_real: $1870.97
# Sell VALIDATION: $37154.60 | Profit_real: $1870.97
# Sell VALIDATION: $41500.88 | Profit_real: $1870.97
# Sell VALIDATION: $41441.16 | Profit_real: $1870.97
# Sell VALIDATION: $42412.43 | Profit_real: $1870.97
# Sell VALIDATION: $43840.29 | Profit_real: $1870.97
# Sell VALIDATION: $44118.45 | Profit_real: $1870.97
# Sell VALIDATION: $44338.80 | Profit_real: $1870.97
# Sell VALIDATION: $43565.11 | Profit_real: $1870.97
# Sell VALIDATION: $42407.94 | Profit_real: $1870.97
# Sell VALIDATION: $42244.47 | Profit_real: $1870.97
# Sell VALIDATION: $42197.52 | Profit_real: $1870.97
# Sell VALIDATION: $42586.92 | Profit_real: $1870.97
# Sell VALIDATION: $44575.20 | Profit_real: $1870.97
# Sell VALIDATION: $43961.86 | Profit_real: $1870.97
# Sell VALIDATION: $40538.01 | Profit_real: $1870.97
# Sell VALIDATION: $40030.98 | Profit_real: $1870.97
# Sell VALIDATION: $40122.16 | Profit_real: $1870.97
# Sell VALIDATION: $38431.38 | Profit_real: $1870.97
# Sell VALIDATION: $37075.28 | Profit_real: $1870.97
# Sell VALIDATION: $38286.03 | Profit_real: $1870.97
# Sell VALIDATION: $37296.57 | Profit_real: $1870.97
# Sell VALIDATION: $38332.61 | Profit_real: $1870.97
# Sell VALIDATION: $39214.22 | Profit_real: $1870.97
# Sell VALIDATION: $39105.15 | Profit_real: $1870.97
# Sell VALIDATION: $37709.79 | Profit_real: $1870.97
# Sell VALIDATION: $43193.23 | Profit_real: $1870.97
# Sell VALIDATION: $44354.64 | Profit_real: $1870.97
# Sell VALIDATION: $43924.12 | Profit_real: $1870.97
# Sell VALIDATION: $42451.79 | Profit_real: $1870.97
# Sell VALIDATION: $39137.61 | Profit_real: $1870.97
# Sell VALIDATION: $39400.59 | Profit_real: $1870.97
# Sell VALIDATION: $38419.98 | Profit_real: $1870.97
# Sell VALIDATION: $38062.04 | Profit_real: $1870.97
# Sell VALIDATION: $38737.27 | Profit_real: $1870.97
# Sell VALIDATION: $41982.93 | Profit_real: $1870.97
# Sell VALIDATION: $39437.46 | Profit_real: $1870.97
# Sell VALIDATION: $38794.97 | Profit_real: $1870.97
# Sell VALIDATION: $38904.01 | Profit_real: $1870.97
# Sell VALIDATION: $37849.66 | Profit_real: $1870.97
# Sell VALIDATION: $39666.75 | Profit_real: $1870.97
# Sell VALIDATION: $39338.79 | Profit_real: $1870.97
# Sell VALIDATION: $41143.93 | Profit_real: $1870.97
# Sell VALIDATION: $40951.38 | Profit_real: $1870.97
# Sell VALIDATION: $41801.16 | Profit_real: $1870.97
# Sell VALIDATION: $42190.65 | Profit_real: $1870.97
# Sell VALIDATION: $41247.82 | Profit_real: $1870.97
# Sell VALIDATION: $41078.00 | Profit_real: $1870.97
# Sell VALIDATION: $42358.81 | Profit_real: $1870.97
# Sell VALIDATION: $42892.96 | Profit_real: $1870.97
# Sell VALIDATION: $43960.93 | Profit_real: $1870.97
# Sell VALIDATION: $44348.73 | Profit_real: $1870.97
# Sell VALIDATION: $44500.83 | Profit_real: $1870.97
# Sell VALIDATION: $46820.49 | Profit_real: $1870.97
# Sell VALIDATION: $47128.00 | Profit_real: $1870.97
# Sell VALIDATION: $47465.73 | Profit_real: $1870.97
# Sell VALIDATION: $47062.66 | Profit_real: $1870.97
# Sell VALIDATION: $45538.68 | Profit_real: $1870.97
# Sell VALIDATION: $46281.64 | Profit_real: $1870.97
# Sell VALIDATION: $45868.95 | Profit_real: $1870.97
# Sell VALIDATION: $46453.57 | Profit_real: $1870.97
# Sell VALIDATION: $46622.68 | Profit_real: $1870.97
# Sell VALIDATION: $45555.99 | Profit_real: $1870.97
# Sell VALIDATION: $43206.74 | Profit_real: $1870.97
# Sell VALIDATION: $43503.85 | Profit_real: $1870.97
# Sell VALIDATION: $42287.66 | Profit_real: $1870.97
# Sell VALIDATION: $42782.14 | Profit_real: $1870.97
# Sell VALIDATION: $42207.67 | Profit_real: $1870.97
# Sell VALIDATION: $39521.90 | Profit_real: $1870.97
# Sell VALIDATION: $40127.18 | Profit_real: $1870.97
# Sell VALIDATION: $41166.73 | Profit_real: $1870.97
# Sell VALIDATION: $39935.52 | Profit_real: $1870.97
# Sell VALIDATION: $40553.46 | Profit_real: $1870.97
# Sell VALIDATION: $40424.48 | Profit_real: $1870.97
# Sell VALIDATION: $39716.95 | Profit_real: $1870.97
# Sell VALIDATION: $40826.21 | Profit_real: $1870.97
# Sell VALIDATION: $41502.75 | Profit_real: $1870.97
# Sell VALIDATION: $41374.38 | Profit_real: $1870.97
# Sell VALIDATION: $40527.36 | Profit_real: $1870.97
# Sell VALIDATION: $39740.32 | Profit_real: $1870.97
# Sell VALIDATION: $39486.73 | Profit_real: $1870.97
# Sell VALIDATION: $39469.29 | Profit_real: $1870.97
# Sell VALIDATION: $40458.31 | Profit_real: $1870.97
# Sell VALIDATION: $38117.46 | Profit_real: $1870.97
# Sell VALIDATION: $39241.12 | Profit_real: $1870.97
# Sell VALIDATION: $39773.83 | Profit_real: $1870.97
# Sell VALIDATION: $38609.82 | Profit_real: $1870.97
# Sell VALIDATION: $37714.88 | Profit_real: $1870.97
# Sell VALIDATION: $38469.09 | Profit_real: $1870.97
# Sell VALIDATION: $38529.33 | Profit_real: $1870.97
# Sell VALIDATION: $37750.45 | Profit_real: $1870.97
# Sell VALIDATION: $39698.37 | Profit_real: $1870.97
# Sell VALIDATION: $36575.14 | Profit_real: $1870.97
# Sell VALIDATION: $36040.92 | Profit_real: $1870.97
# Sell VALIDATION: $35501.95 | Profit_real: $1870.97
# Sell VALIDATION: $34059.27 | Profit_real: -$1442.69
# Sell VALIDATION: $30296.95 | Profit_real: -$1442.69
# Sell VALIDATION: $31022.91 | Profit_real: -$1442.69
# Sell VALIDATION: $28936.36 | Profit_real: -$1442.69
# Sell VALIDATION: $29047.75 | Profit_real: -$1442.69
# Sell VALIDATION: $29283.10 | Profit_real: -$1442.69
# Sell VALIDATION: $30101.27 | Profit_real: -$1442.69
# Sell VALIDATION: $31305.11 | Profit_real: -$1442.69
# Sell VALIDATION: $29862.92 | Profit_real: -$1442.69
# Sell VALIDATION: $30425.86 | Profit_real: -$1442.69
# Sell VALIDATION: $28720.27 | Profit_real: -$1442.69
# Sell VALIDATION: $30314.33 | Profit_real: -$1442.69
# Sell VALIDATION: $29200.74 | Profit_real: -$1442.69
# Sell VALIDATION: $29432.23 | Profit_real: -$1442.69
# Sell VALIDATION: $30323.72 | Profit_real: -$1442.69
# Sell VALIDATION: $29098.91 | Profit_real: -$1442.69

# %%
plt.title('Profits over training')
plt.plot(profits_global, '-o')

# %% [markdown]
# # Double Q-learning with target and estimator Networks

# %% [markdown]
# This is the algorithm we are employing here:
#
# ![title](./blog_stuff/dqn_target.png)
#
# For more details on implementation read the blog [here](). This uses the selection and evaluation \[NN\] functions.

# %%
# functions to copy parameters between two networks
def copy_parameters(q_network, target_network, sess):
    # q_network (source) to target_network (target)
    # sess: tensorflow session
    
    # source
    source_params = [t for t in tf.trainable_variables() if t.name.startswith(q_network.scope)]
    source_params = sorted(source_params, key = lambda v: v.name)
    
    # target
    target_params = [t for t in tf.trainable_variables() if t.name.startswith(target_network.scope)]
    target_params = sorted(target_params, key = lambda v: v.name)
    
    # do assign operations in loop
    for s_v, t_v in zip(source_params, target_params):
        op = t_v.assign(s_v)
        sess.run(op)

# %%
class DoubleDQN():
    # initialization function
    def __init__(self, input_dim, scope, is_eval = False):
        # input_dim: state size
        # is_eval: is being evaluated
        # scope: scope of the model
        self.state_size = input_dim
        self.action_space = 3 # sell, sit, buy
        self.scope = scope # name of scope

        # code to load previously trained model --> skip for now
        # self.model = load_model("models/" + model_name) if is_eval else self._model()
        self._build_model()
        self._build_loss()

    # inhouse functions
    def _build_model(self):
        self.input_placeholder = tf.placeholder(tf.float32, [None, self.state_size], name = 'inputs')
        self.q_placeholder = tf.placeholder(tf.float32, [None, self.action_space], name = 'q_value')

        # layers
        h1 = tf.contrib.layers.fully_connected(self.input_placeholder, 64)
        h2 = tf.contrib.layers.fully_connected(h1, 32)
        h3 = tf.contrib.layers.fully_connected(h2, 8)
        self.action_pred = tf.contrib.layers.fully_connected(h3, self.action_space, activation_fn = tf.nn.softmax)

    def _build_loss(self):
        self.loss = tf.reduce_mean(tf.square(self.q_placeholder - self.action_pred))
        self.update_step = tf.train.AdamOptimizer(0.001).minimize(self.loss)
        
    # user callable functions
    def save_model(self, frozen = False):
        # code to save the model as frozen inference graph (optional) or 
        # checkpoint file (default)
        if frozen:
            # convert to frozen graph here
            model_path = 'some_path'
            print('Model saved at {0}'.format(some_path))
            return
        return
    
    # no need for operation functions since everything is called from outside

# %%
def train_dqn(q_network,
              target_network,
              sess,
              data,
              max_mem_size = 1000,
              num_episodes = 50,
              train_target_every = 2,
              gamma = 0.99,
              epsilon_start = 0.99,
              epsilon_end = 0.001,
              epsilon_decay = 0.995):
    # function variables
    train_global_step = 0 # global step needed in parameter update
    train_loss = [] # training loss in each episode
    train_profits = [] # for profits in each episode
    
    # memory_buffer
    memory_buffer = []
    
    # initialize variables
    sess.run(tf.global_variables_initializer())
    
    # init stuff
    epsilon = epsilon_start
    
    # iterate over each episode
    for ep in range(num_episodes):
        # for each training episode
        state = get_state(data, 0, window_size + 1)
        
        # init values for new episode
        total_profit = 0.0 # total profit in this episode
        # q_network.inventory = [] # holdings by q_network
        inventory = [] # inventory for this episode
        ep_loss = [] # total loss in this episode
        
        for t in tqdm(range(len_data)):
            # take action according to epsilon greedy policy
            if np.random.random() > epsilon:
                action = np.random.randint(q_network.action_space)
            else:
                feed_dict = {q_network.input_placeholder: state}
                action = sess.run(q_network.action_pred, feed_dict = feed_dict)
                action = np.argmax(action[0])
            
            # next state
            next_state = get_state(data, t + 1, window_size + 1)
            reward = 0
            
            # now go according to the actions
            if action == 2:
                # buy
                inventory.append(data[t])
                if LOG:
                    print('Buy:' + format_price(data[t]))
                    
            elif action == 0 and len(inventory) > 0:
                bought_price = inventory.pop(0) # remove the first element and return the value
                profit = data[t] - bought_price # profit this transaction
                reward = max(data[t] - bought_price, 0) # reward
                total_profit += profit # add to total profit
                if LOG:
                    print("Sell: " + format_price(data[t]) + " | Profit: " + format_price(profit))
                    
            # condition for done
            done = t == len_data - 1
            
            # add to memory and make sure it's of fixed size
            memory_buffer.append((state, action, reward, next_state, done))
            if len(memory_buffer) > max_mem_size:
                memory_buffer.pop(0)
            
            # update state
            state = next_state
            
            # train the model
            if len(memory_buffer) > batch_size:
                
                # sample minibatches here
                mini_batch = memory_buffer[-batch_size:]
                    
                # calculate q_value and target_values
                for state_t, action_t, reward_t, next_state_t, done_t in mini_batch:
                    # condition for calculating y_j
                    if done_t:
                        target_pred = reward
                    
                    else:
                        feed_dict = {target_network.input_placeholder: next_state_t}
                        target_pred = sess.run(target_network.action_pred, feed_dict = feed_dict)
                        target_value = reward_t + gamma*np.amax(target_pred[0])
                    
                    # q_value
                    feed_dict = {q_network.input_placeholder: state_t}
                    q_values = sess.run(q_network.action_pred, feed_dict = feed_dict)
                    q_values[0][action_t] = target_value
                    
                    # drop epsilon value after every action taken
                    if epsilon > epsilon_end:
                        epsilon *= epsilon_decay
                    
                    # update the q_network parameters
                    feed_dict = {q_network.input_placeholder: state_t,
                                 q_network.q_placeholder: q_values}
                    loss, _ = sess.run([q_network.loss, q_network.update_step], feed_dict = feed_dict)
                    
                    # update the lists
                    ep_loss.append(loss)
                    
                    # update target network
                    train_global_step += 1
                    if ep % train_target_every == 0:
                        copy_parameters(q_network, target_network, sess)
                        
        # update the outer values
        train_loss.append(ep_loss)
        train_profits.append(total_profit)
        
        # print val
        print('[*]Episode: {0}, loss: {1}, profits: {2}, epsilon: {3}'\
              .format(ep + 1, np.mean(train_loss[-1]), train_profits[-1], epsilon))
    
    # return the values
    return train_loss, train_profits

# %%
# run the model
q_network = DoubleDQN(window_size, 'q_network')
target_network = DoubleDQN( window_size, 'target_network')
sess = tf.Session()
loss, profits = train_dqn(q_network, target_network, sess, data)
# Out:
# 100%|██████████| 5360/5360 [05:52<00:00, 15.23it/s]
#   0%|          | 2/5360 [00:00<08:37, 10.36it/s]
# [*]Episode: 1, loss: 2090.693359375, profits: 92243.883383, epsilon: 0.0009954452565571535
#  46%|████▌     | 2454/5360 [02:38<03:08, 15.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-84652a47ccd4> in <module>()
#       3 target_network = Agent_DQN( window_size, 'target_network')
#       4 sess = tf.Session()
# ----> 5 loss, profits = train_dqn(q_network, target_network, sess, data)
#
# <ipython-input-7-d3bdbf02cd1d> in train_dqn(q_network, target_network, sess, data, max_mem_size, num_episodes, train_target_every, gamma, epsilon_start, epsilon_end, epsilon_decay)
#     103                     feed_dict = {q_network.input_placeholder: state_t,
#     104                                  q_network.q_placeholder: q_values}
# --> 105                     loss, _ = sess.run([q_network.loss, q_network.update_step], feed_dict = feed_dict)
#     106
#     107                     # update the lists
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %% [markdown]
# # Dueling DQN (DDQN)
#
# Below is the architecture and code for dueling DQN. In this architecture, the network calculates two sepearate values Advantage `A(s,a)` and value `v(s)` for any given state, the q-value is then given by `Q(s,a) = A(s,a) + v(s)`
#
# ![title](./blog_stuff/dueling_dqn.png)

# %%
class DDQN():
    def __init__(self, input_dim, scope):
        self.state_size = input_dim
        self.scope = scope
        self.action_space = 3
        
        # placeholders
        self.input_placeholder = tf.placeholder(tf.float32, [None, self.state_size], name = 'inputs')
        self.q_placeholder = tf.placeholder(tf.float32, [None, self.action_space], name = 'q_value')
        
        # build model
        self._build_model()
        self._build_loss()
        
    def _build_model(self):
        # layers
        h1 = tf.contrib.layers.fully_connected(self.input_placeholder, 64)
        common_h2 = tf.contrib.layers.fully_connected(h1, 32)
        
        # value network layers
        val_h3 = tf.contrib.layers.fully_connected(common_h2, 8)
        self.value = tf.contrib.layers.fully_connected(val_h3, 1)
        
        # advantage network layers
        adv_h3 = tf.contrib.layers.fully_connected(common_h2, 16)
        self.advantage = tf.contrib.layers.fully_connected(adv_h3, self.action_space)
        
        # get the final q value
        # tensorflow automatically perform the calculation of type [1,1] + [1,3] = [1,3]
        # Q(s,a) = V(s) + (A(s,a) - 1/|A|(sum(A(s,a))))
        self.action_pred = self.value + (self.advantage - tf.reduce_mean(self.advantage, axis = 1, keepdims = True)) 
        
    def _build_loss(self):
        self.loss = tf.reduce_mean(tf.square(self.action_pred - self.q_placeholder))
        self.train_step = tf.train.AdamOptimizer().minimize(self.loss)

# %%
def train_ddqn(network,
               sess,
               data,
               max_mem_size = 1000,
               num_episodes = 50,
               gamma = 0.99,
               epsilon_start = 0.99,
               epsilon_end = 0.001,
               epsilon_decay = 0.995):
    # function variables
    train_global_step = 0 # global step needed in parameter update
    train_loss = [] # training loss in each episode
    train_profits = [] # for profits in each episode
    
    # memory_buffer
    memory_buffer = []
    
    # initialize variables
    sess.run(tf.global_variables_initializer())
    
    # init stuff
    epsilon = epsilon_start
    
    # iterate over each episode
    for ep in range(num_episodes):
        # for each training episode
        state = get_state(data, 0, window_size + 1)
        
        # init values for new episode
        total_profit = 0.0 # total profit in this episode
        # q_network.inventory = [] # holdings by q_network
        inventory = [] # inventory for this episode
        ep_loss = [] # total loss in this episode
        
        for t in tqdm(range(len_data)):
            # take action according to epsilon greedy policy
            if np.random.random() > epsilon:
                action = np.random.randint(q_network.action_space)
            else:
                feed_dict = {q_network.input_placeholder: state}
                action = sess.run(q_network.action_pred, feed_dict = feed_dict)
                action = np.argmax(action[0])
            
            # next state
            next_state = get_state(data, t + 1, window_size + 1)
            reward = 0
            
            # now go according to the actions
            if action == 2:
                # buy
                inventory.append(data[t])
                if LOG:
                    print('Buy:' + format_price(data[t]))
                    
            elif action == 0 and len(inventory) > 0:
                bought_price = inventory.pop(0) # remove the first element and return the value
                profit = data[t] - bought_price # profit this transaction
                reward = max(data[t] - bought_price, 0) # reward
                total_profit += profit # add to total profit
                if LOG:
                    print("Sell: " + format_price(data[t]) + " | Profit: " + format_price(profit))
                    
            # condition for done
            done = t == len_data - 1
            
            # add to memory and make sure it's of fixed size
            memory_buffer.append((state, action, reward, next_state, done))
            if len(memory_buffer) > max_mem_size:
                memory_buffer.pop(0)
            
            # update state
            state = next_state
            
            # train the model
            if len(memory_buffer) > batch_size:
                
                # sample minibatches here
                mini_batch = memory_buffer[-batch_size:]
                    
                # calculate q_value and target_values
                for state_t, action_t, reward_t, next_state_t, done_t in mini_batch:
                    # condition for calculating y_j
                    if done_t:
                        target_pred = reward
                    
                    else:
                        feed_dict = {network.input_placeholder: next_state_t}
                        network_pred = sess.run(network.action_pred, feed_dict = feed_dict)
                        target_value = reward_t + gamma*np.amax(network_pred[0])
                    
                    # q_value
                    feed_dict = {network.input_placeholder: state_t}
                    q_values = sess.run(network.action_pred, feed_dict = feed_dict)
                    q_values[0][action_t] = target_value
                    
                    # drop epsilon value after every action taken
                    if epsilon > epsilon_end:
                        epsilon *= epsilon_decay
                    
                    # update the q_network parameters
                    feed_dict = {network.input_placeholder: state_t,
                                 network.q_placeholder: q_values}
                    loss, _ = sess.run([q_network.loss, q_network.train_step], feed_dict = feed_dict)
                    
                    # update the lists
                    ep_loss.append(loss)
                    
        # update the outer values
        train_loss.append(ep_loss)
        train_profits.append(total_profit)
        
        # print val
        print('[*]Episode: {0}, loss: {1}, profits: {2}, epsilon: {3}'\
              .format(ep + 1, np.mean(train_loss[-1]), train_profits[-1], epsilon))
    
    # return the values
    return train_loss, train_profits

# %%
# run the model
q_network = DDQN(window_size, 'q_network')
sess = tf.Session()
loss, profits = train_ddqn(q_network, sess, data)
# Out:
#  39%|███▉      | 1089/2806 [00:28<00:44, 38.89it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in exp
#
# 100%|██████████| 2806/2806 [01:13<00:00, 38.35it/s]
# [*]Episode: 1, loss: 11649130.0, profits: 3115576.554851999, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:12<00:00, 38.64it/s]
# [*]Episode: 2, loss: 4245829.0, profits: 613191.5562389987, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:13<00:00, 38.05it/s]
# [*]Episode: 3, loss: 2730830.5, profits: 812223.9562080001, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:12<00:00, 38.45it/s]
# [*]Episode: 4, loss: 532943.125, profits: 21660.86889399993, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:13<00:00, 38.12it/s]
# [*]Episode: 6, loss: 1491655.625, profits: 527203.1079589986, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:14<00:00, 37.83it/s]
# [*]Episode: 7, loss: 1905196.5, profits: 62771.3741300001, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:13<00:00, 38.03it/s]
# [*]Episode: 8, loss: 1792251.125, profits: 641813.1306390003, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:15<00:00, 37.22it/s]
# [*]Episode: 9, loss: 2011339.875, profits: 414248.0912739997, epsilon: 0.0009954452565571535
# 100%|██████████| 2806/2806 [01:15<00:00, 37.10it/s]
# [*]Episode: 10, loss: 594221.75, profits: 302986.91428699973, epsilon: 0.0009954452565571535
#  11%|█         | 300/2806 [00:07<01:05, 38.44it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
